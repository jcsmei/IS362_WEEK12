# %%
import json
import urllib2
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# Import the relevent modules
#
# Then get the API key from http://developer.nytimes.com/
#
# Create a request to the NY Times API; Top Stories will be used for this assignment.

# %%
api_key =  '32b3947ff56e4b4080f99909bc993c5c'
web_url = 'https://api.nytimes.com/svc/topstories/v2/home.json?'

requests = web_url+'&api-key='+api_key
response = urllib2.urlopen(requests).read().decode('utf-8')

top_st = json.loads(response)
top_st
# Out:
# {u'copyright': u'Copyright (c) 2018 The New York Times Company. All Rights Reserved.',
#  u'last_updated': u'2018-11-25T16:17:10-05:00',
#  u'num_results': 39,
#  u'results': [{u'abstract': u'Coal, the most polluting of energy sources, shows no sign of disappearing three years after the Paris agreement, when world leaders promised decisive action against global warming.',
#    u'byline': u'By SOMINI SENGUPTA',
#    u'created_date': u'2018-11-24T09:37:03-05:00',
#    u'des_facet': [u'Coal',
#     u'Global Warming',
#     u'Greenhouse Gas Emissions',
#     u'United Nations Framework Convention on Climate Change',
#     u'Alternative and Renewable Energy'],
#    u'geo_facet': [u'Vietnam', u'India', u'China', u'Telangana (India)'],
#    u'item_type': u'Article',
#    u'kicker': u'',
#    u'material_type_facet': u'',
#    u'multimedia': [{u'caption': u'An open pit mine in Burdwan, West Bengal, India. Coal is the single largest source of electricity worldwide.',
# ...

# %% [markdown]
# #### Load the results into a pandas DataFrame

# %%
df = pd.DataFrame(data=top_st['results'])
df.head(10)
# Out:
#                                             abstract  \
# 0  Coal, the most polluting of energy sources, sh...
# 1  Friday's government report, detailing in stark...
# 2  A decade ago, the U.S. mandated the use of veg...
# 3  The Chinese police are barring Victor and Cynt...
# 4  Since the world’s longest sea bridge opened la...
# 5  Built in just five years, Beijing’s new airpor...
# 6  The settlement reached at a summit meeting on ...
# 7  Prime Minister Theresa May obtained the approv...
# 8  President Trump insists that no migrant will b...
# 9  The goal is to open pathways for doctors and h...
#
#                                   byline               created_date  \
# 0                     By SOMINI SENGUPTA  2018-11-24T09:37:03-05:00
# 1                     By CORAL DAVENPORT  2018-11-25T14:51:27-05:00
# 2                   By ABRAHM LUSTGARTEN  2018-11-20T05:00:03-05:00
# 3    By EDWARD WONG and MICHAEL FORSYTHE  2018-11-25T13:50:45-05:00
# ...
